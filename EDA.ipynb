# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient('mongodb://localhost:27017');
print("Connection Successful")
#client.close()
# Out:
# Connection Successful

# %%
db= client.test
animals= db.animals
cursor_a = db['animals'].find()
df_animals =  pd.DataFrame(list(cursor_a))
df_animals
# Out:
#                           _id            animalSettlement caravanaNumber  \
# 0    62d6e9920408c608acb6fdd0  [620e6e5e60543d0026a01f0e]           CAR9
# 1    62d6e9d30408c608acb6fe08  [620e6e5e60543d0026a01f0e]          CAR71
# 2    62d98db9a30a66002645c287  [620e6e5e60543d0026a01f0e]          CAR52
# 3    62d99045a30a66002645c384  [620e6e5e60543d0026a01f0e]         CAR169
# 4    62d9a88c0223ce002612afed  [620e6e5e60543d0026a01f0e]          CAR19
# ..                        ...                         ...            ...
# 625  642367fd0dac550030136043  [63ecf27ba9f1a40025792acf]       TBOZAVI9
# 626  642367fd0dac550030136047  [63ecf27ba9f1a40025792acf]      TBOZAVI11
# 627  642367fd0dac550030136045  [63ecf27ba9f1a40025792acf]      TBOZAVI10
# 628  6424319990adbe6da4fb1c8a  [63efd78d65980f4378711b6f]     PRUEBA FAS
# 629  642aeed40dac550030174fac  [63e6454922ee080030ba8728]     PRUEBA SEN
#
#     animalType  weight   birthDay            breed isPregmant dateOfBirth  \
# ...

# %%
datos_animales = []
for db in db.find():
    diccionario = db["animals"]
    datos.append(diccionario)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/5_/gzf1wsls3f76y2tqntkbp17h0000gp/T/ipykernel_70628/3577357913.py in <module>
#       1 datos_animales = []
# ----> 2 for db in db.find():
#       3     diccionario = db["animals"]
#       4     datos.append(diccionario)
#
# AttributeError: 'dict' object has no attribute 'find'

# %%
datarows= db.datarows
cursor_dr = db['datarows'].find()
df_dr =  pd.DataFrame(list(cursor_dr))
df_dr
# Out:
#                               _id  \
# 0        62e93bc957a36c0025d91f21
# 1        62e93bee57a36c0025d91f23
# 2        62e93bf557a36c0025d91f29
# 3        62e93bf857a36c0025d91f2b
# 4        62e93bfa57a36c0025d91f2d
# ...                           ...
# 1296775  642d9b18d4035700302e32a7
# 1296776  642d9b1bd4035700302e32ad
# 1296777  642d9b20d4035700302e32b3
# 1296778  642d9b24d4035700302e32b9
# 1296779  642d9b2cd4035700302e32bf
#
#                                                dataRowData              UUID  \
# 0        {'timestamp': '2022-08-02T14:59:21.948Z', 'mac...  0004A30B00F80B96
# 1        {'timestamp': '2022-02-08T14:59:57', 'lat': -3...  0004A30B00F82BD2
# 2        {'timestamp': '2022-08-02T15:00:05.618Z', 'mac...  0004A30B00F7FC71
# 3        {'timestamp': '2022-08-02T15:00:08.053Z', 'mac...  0004A30B00F7FC71
# 4        {'timestamp': '2022-08-02T15:00:10.203Z', 'mac...  0004A30B00F82BD2
# ...                                                    ...               ...
# ...

# %%
devices= db.devices
cursor_dev = db['devices'].find()
df_dev =  pd.DataFrame(list(cursor_dev))
df_dev
# Out:
#                           _id deviceType deviceFirmwareVersion  \
# 0    62d56cc2e71f68426833cc74   CARAVANA                  2222
# 1    62d6e9fc0408c608acb6fe31   CARAVANA                  2222
# 2    62d99152a30a66002645c414   CARAVANA                  2222
# 3    62d9a95f0223ce002612b082   CARAVANA                  2222
# 4    62d9ad5d0223ce002612b4e5   CARAVANA                  2222
# ..                        ...        ...                   ...
# 568  642360b02db4a76760913a58     COLLAR                  2200
# 569  64236c77cf291b10b4ea5575     COLLAR                  2200
# 570  64236c77cf291b10b4ea557a     COLLAR                  2200
# 571  64236c77cf291b10b4ea557c     COLLAR                  2200
# 572  642448faf8f189037068ccc1   CARAVANA                 2.2.0
#
#      deviceMACAddress            deviceAnimalID  __v
# 0        BC27B1A003FE  640f6ef10c8f4c1edc6767e4    0
# 1        E0402C1C41C3  642354190dac5500301350d0    0
# ...

# %%
#settcount= db.settlementithcounts
cursor_sec = db['settlementithcounts'].find()
df_sec =  pd.DataFrame(list(cursor_sec))
df_sec
# Out:
#                             _id              settlementId   ITH  \
# 0      62c7f1aedb5dcb31707223a8  620e6e5e60543d0026a01f0e  85.0
# 1      62cd3f774e549d1fa8a49127  620e6e5e60543d0026a01f0e  40.0
# 2      62cac4e7f7ba57581cc7333a  620e6e5e60543d0026a01f0e  85.0
# 3      62cac5dd9a70241d101c8044  620e6e5e60543d0026a01f0e   0.0
# 4      62cac836ea09d2322467a8c3  620e6e5e60543d0026a01f0e  51.0
# ...                         ...                       ...   ...
# 17775  642d8cf1b239c60030f95c51  63ecf27ba9f1a40025792acf  71.0
# 17776  642d8cf2b239c60030f95c54  642c0b596490e600305e1819  69.0
# 17777  642d9b01d4035700302e3288  620e6e5e60543d0026a01f0e  70.0
# 17778  642d9b02d4035700302e328a  642c0b596490e600305e1819  68.0
# 17779  642d9b02d4035700302e328c  63ecf27ba9f1a40025792acf  72.0
#
#                     createdAt               updatedAt  __v
# 0     2022-07-08 08:58:22.542 2022-07-08 08:58:22.542    0
# 1     2022-07-12 09:31:35.287 2022-07-12 09:31:35.287    0
# ...

# %%
cursor_set = db['settlements'].find()
df_set =  pd.DataFrame(list(cursor_set))
df_set
# Out:
#                         _id  \
# 0  620e6e5e60543d0026a01f0e
# 1  63877cd7e1ed590030662d0a
# 2  63e641fc22ee080030ba838b
# 3  63e6454922ee080030ba8728
# 4  63efd78d65980f4378711b6f
# 5  63ecf27ba9f1a40025792acf
# 6  63ff75624c2d6d003084c117
# 7  642b1d27cc00091984864f0a
# 8  642c0b596490e600305e1819
#
#                                         enabledUsers  \
# 0  [6201245070900d002592d7ec, 636c17ea2bd5b200305...
# 1                         [6201245070900d002592d7ec]
# 2                         [6201245070900d002592d7ec]
# 3                         [6201245070900d002592d7ec]
# 4                         [6201245070900d002592d7ec]
# 5  [6201245070900d002592d7ec, 63ecb2e2a9f1a400257...
# 6                         [6201245070900d002592d7ec]
# 7                         [6201245070900d002592d7ec]
# 8                         [6201245070900d002592d7ec]
#
#                                                plots  \
# 0  [63b55f4b973f9f35c0c5b37d, 63b55f4b973f9f35c0c...
# ...
